# %%
import pandas as pd

# %% [markdown]
# ### Series object

# %%
s = pd.Series([45,67,42,34,89])

# %%
s
# Out:
# 0    45
# 1    67
# 2    42
# 3    34
# 4    89
# dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.size
# Out:
# 5

# %%
s[3]
# Out:
# 34

# %%
s = pd.Series([45,67,42,34,89], index=range(100,105))

# %%
s
# Out:
# 100    45
# 101    67
# 102    42
# 103    34
# 104    89
# dtype: int64

# %%
s[103]
# Out:
# 34

# %% [markdown]
# # Dataframe

# %%
roll = pd.Series([1,2,3,4,5])
name = pd.Series(['Natasha','Ajinkya','Kaushik','Tushar','Riya'])
marks = pd.Series([67,78,81,69,73])

# %%
df = pd.DataFrame({
    'roll': roll,
    'name': name,
    'marks': marks
})

# %%
df
# Out:
#    roll     name  marks
# 0     1  Natasha     67
# 1     2  Ajinkya     78
# 2     3  Kaushik     81
# 3     4   Tushar     69
# 4     5     Riya     73

# %%
df.shape
# Out:
# (5, 3)

# %%
df.size
# Out:
# 15

# %%
df.columns
# Out:
# Index(['roll', 'name', 'marks'], dtype='object')

# %% [markdown]
# ### Importing the data

# %%
# location: https://mitu.co.in/dataset
# data: download all the files starting from student*
# for easier loading put those files in the same folder as ur jupyter
# notebook

# %%
pwd
# Out:
# '/home/aditya/ADITYA/DACOE_KARAD'

# %%
df = pd.read_csv('student.csv')
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
headers = ['A','B','C','D','E']
df1 = pd.read_csv('student1.csv', names = headers)
df1
# Out:
#     A        B   C      D   E
# 0   1     anil  TE  56.77  22
# 1   2     amit  TE  59.77  21
# 2   3   aniket  BE  76.88  19
# 3   4  ajinkya  TE  69.66  20
# 4   5     asha  TE  63.28  20
# 5   6   ayesha  BE  49.55  20
# 6   7     amar  BE  65.34  19
# 7   8    amita  BE  68.33  23
# 8   9     amol  TE  56.75  20
# 9  10    anmol  BE  78.66  21

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.shape
# Out:
# (10, 5)

# %%
df.size
# Out:
# 50

# %%
df.dtypes
# Out:
# roll       int64
# name      object
# class     object
# marks    float64
# age        int64
# dtype: object

# %%
df.head(3)
# Out:
#    roll    name class  marks  age
# 0     1    anil    TE  56.77   22
# 1     2    amit    TE  59.77   21
# 2     3  aniket    BE  76.88   19

# %%
df.tail()
# Out:
#    roll    name class  marks  age
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    10 non-null     int64
#  1   name    10 non-null     object
#  2   class   10 non-null     object
#  3   marks   10 non-null     float64
#  4   age     10 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 532.0+ bytes

# %%
df.describe()
# Out:
#            roll      marks        age
# count  10.00000  10.000000  10.000000
# mean    5.50000  64.499000  20.500000
# std     3.02765   9.207179   1.269296
# min     1.00000  49.550000  19.000000
# 25%     3.25000  57.520000  20.000000
# 50%     5.50000  64.310000  20.000000
# 75%     7.75000  69.327500  21.000000
# max    10.00000  78.660000  23.000000

# %%
# slicing

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.iloc[3:8,1:4]
# Out:
#       name class  marks
# 3  ajinkya    TE  69.66
# 4     asha    TE  63.28
# 5   ayesha    BE  49.55
# 6     amar    BE  65.34
# 7    amita    BE  68.33

# %%
x = df.iloc[3:8,1:4]
x
# Out:
#       name class  marks
# 3  ajinkya    TE  69.66
# 4     asha    TE  63.28
# 5   ayesha    BE  49.55
# 6     amar    BE  65.34
# 7    amita    BE  68.33

# %%
df.iloc[2:3,1]
# Out:
# 2    aniket
# Name: name, dtype: object

# %%
df.iloc[2,1]
# Out:
# 'aniket'

# %%
df.iloc[[3,4,6,7],1:4]
# Out:
#       name class  marks
# 3  ajinkya    TE  69.66
# 4     asha    TE  63.28
# 6     amar    BE  65.34
# 7    amita    BE  68.33

# %%
df.loc[:, 'name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.loc[:, ['name', 'marks']]
# Out:
#       name  marks
# 0     anil  56.77
# 1     amit  59.77
# 2   aniket  76.88
# 3  ajinkya  69.66
# 4     asha  63.28
# 5   ayesha  49.55
# 6     amar  65.34
# 7    amita  68.33
# 8     amol  56.75
# 9    anmol  78.66

# %%
df['name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.drop(5)
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.drop([4,6,7])
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 5     6   ayesha    BE  49.55   20
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.drop('name', axis = 1, inplace= True)

# %%
df
# Out:
#    roll class  marks  age
# 0     1    TE  56.77   22
# 1     2    TE  59.77   21
# 2     3    BE  76.88   19
# 3     4    TE  69.66   20
# 4     5    TE  63.28   20
# 5     6    BE  49.55   20
# 6     7    BE  65.34   19
# 7     8    BE  68.33   23
# 8     9    TE  56.75   20
# 9    10    BE  78.66   21

# %%
# Rename

# %%
cols = {'roll': 'id', 'marks': 'grade'}

# %%
df.rename(columns= cols, inplace= True)

# %%
df
# Out:
#    id class  grade  age
# 0   1    TE  56.77   22
# 1   2    TE  59.77   21
# 2   3    BE  76.88   19
# 3   4    TE  69.66   20
# 4   5    TE  63.28   20
# 5   6    BE  49.55   20
# 6   7    BE  65.34   19
# 7   8    BE  68.33   23
# 8   9    TE  56.75   20
# 9  10    BE  78.66   21

# %%
ind = {1: 'first', 2: 'second'}

# %%
df.rename(index= ind)
# Out:
#         id class  grade  age
# 0        1    TE  56.77   22
# first    2    TE  59.77   21
# second   3    BE  76.88   19
# 3        4    TE  69.66   20
# 4        5    TE  63.28   20
# 5        6    BE  49.55   20
# 6        7    BE  65.34   19
# 7        8    BE  68.33   23
# 8        9    TE  56.75   20
# 9       10    BE  78.66   21

# %%
df
# Out:
#    id class  grade  age
# 0   1    TE  56.77   22
# 1   2    TE  59.77   21
# 2   3    BE  76.88   19
# 3   4    TE  69.66   20
# 4   5    TE  63.28   20
# 5   6    BE  49.55   20
# 6   7    BE  65.34   19
# 7   8    BE  68.33   23
# 8   9    TE  56.75   20
# 9  10    BE  78.66   21

# %%
# sorting

# %%
df.sort_values(by= 'grade', ascending= False)
# Out:
#    id class  grade  age
# 9  10    BE  78.66   21
# 2   3    BE  76.88   19
# 3   4    TE  69.66   20
# 7   8    BE  68.33   23
# 6   7    BE  65.34   19
# 4   5    TE  63.28   20
# 1   2    TE  59.77   21
# 0   1    TE  56.77   22
# 8   9    TE  56.75   20
# 5   6    BE  49.55   20

# %%
# methods

# %%
df['grade'].sum()
# Out:
# 644.9899999999999

# %%
df['grade'].median()
# Out:
# 64.31

# %%
df['grade'].min()
# Out:
# 49.55

# %%
# string operations

# %%
df = pd.read_csv('student.csv')
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df['name'].str.upper()
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       ASHA
# 5     AYESHA
# 6       AMAR
# 7      AMITA
# 8       AMOL
# 9      ANMOL
# Name: name, dtype: object

# %%
df['name'].str.swapcase()
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       ASHA
# 5     AYESHA
# 6       AMAR
# 7      AMITA
# 8       AMOL
# 9      ANMOL
# Name: name, dtype: object

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df['name'].str.startswith('an')
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9     True
# Name: name, dtype: bool

# %%
gender = ['m','m','m','m','f','f','m','f','m','m']

# %%
df['Gender'] = gender

# %%
df
# Out:
#    roll     name class  marks  age Gender
# 0     1     anil    TE  56.77   22      m
# 1     2     amit    TE  59.77   21      m
# 2     3   aniket    BE  76.88   19      m
# 3     4  ajinkya    TE  69.66   20      m
# 4     5     asha    TE  63.28   20      f
# 5     6   ayesha    BE  49.55   20      f
# 6     7     amar    BE  65.34   19      m
# 7     8    amita    BE  68.33   23      f
# 8     9     amol    TE  56.75   20      m
# 9    10    anmol    BE  78.66   21      m

# %%
# Boolean filtering

# %%
mark = df['marks'] > 60
mark
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8    False
# 9     True
# Name: marks, dtype: bool

# %%
df[mark]
# Out:
#    roll     name class  marks  age Gender
# 2     3   aniket    BE  76.88   19      m
# 3     4  ajinkya    TE  69.66   20      m
# 4     5     asha    TE  63.28   20      f
# 6     7     amar    BE  65.34   19      m
# 7     8    amita    BE  68.33   23      f
# 9    10    anmol    BE  78.66   21      m

# %%
data1 = df[(df['marks']> 60) & (df['class'] == 'BE')]

# %%
data1
# Out:
#    roll    name class  marks  age Gender
# 2     3  aniket    BE  76.88   19      m
# 6     7    amar    BE  65.34   19      m
# 7     8   amita    BE  68.33   23      f
# 9    10   anmol    BE  78.66   21      m

# %%
# export the data

# %%
data1.to_csv('output.csv', index= False)
